# %% [markdown]
# # Notes
# * try multiple blocks 3,5,6,7
# * try cross validation
# * try bagging samples.
# * try one month at a time
# * try one day at a time.
# For LA sanfrancisco
#
# For NYC- Manhattan
#
# * Try hierarchical learning.

# %%
from lib import gradient_mixed
from lib import visualize
from lib import mixmem_aux

import pandas as pd
import math
import random
import numpy as np
import scipy as scp
import scipy.stats as stats
import matplotlib.pyplot as plt

gradient_descent = gradient_mixed.gradient_descent
realistic_initial = gradient_mixed.realistic_initial
likelihood = mixmem_aux.likelihood
mu_likelihood = mixmem_aux.mu_likelihood

scatterplot_city = visualize.scatterplot_city
block_omegas = visualize.block_omegas

# %%
LAdf = pd.read_csv("../data/cleaned/LA16_cleaned_final_no_weekend.csv")
LA_stations_dups = list(LAdf['start_station_id'])
LA_lat = list(LAdf['start_lat'])
LA_lon = list(LAdf['start_lon'])
LA_station_info = dict(zip(LA_stations_dups, zip(LA_lat, LA_lon)))
LA_stations = list(set(LA_stations_dups))
LA_stations.sort()
LA_N = len(LA_stations)
LA_matrix = np.zeros([LA_N, LA_N, 24])
for index, row in LAdf.iterrows():
    i = LA_stations.index(row['start_station_id'])
    j = LA_stations.index(row['end_station_id'])
    t = int(row['start_time'].split(':')[0].split(' ')[1])
    LA_matrix[i, j, t] += 1

# %% [markdown]
# # Non-negative matrix factorization

# %%
from copy import copy
LA_2d=np.reshape(LA_matrix,[LA_N**2,24])
summed=list(np.sum(LA_2d,1))
indices=sorted(range(LA_N), key=lambda k: -summed[k])
plt.imshow(LA_2d[indices,:][10:20])
def poiss_prob(model,data):
    m2=copy(model)
    m2[m2==0]=1
    return np.sum(model-data*np.log(m2))

def mat_obj(phi,psi,data):
    #print(np.shape(phi))
    #print(np.shape(psi))
    return poiss_prob(np.matmul(phi,psi),data)

from scipy.optimize import minimize
nc=4
phi_0=np.random.random([LA_N**2,nc])
psi_0=np.random.random([nc,24])

#np.matmul(phi_0,psi_0)
phi_1=minimize(lambda L :mat_obj(np.reshape(L,[LA_N**2,nc]),psi_0,LA_2d),phi_0[:],bounds=nc*LA_N**2*[(0,1E4)]).x

# %%
LA_fit=[];
numiter=10000
numblocks=10
r0,c0=realistic_initial(LA_matrix,LA_N,numblocks)
LAr_fit, LAc_fit, wr, wc = \
gradient_descent(LA_matrix, r0, c0, N=numiter,sig_digs=3, N_stable=600, nblocks = numblocks, verbose_time = 100)
# Out:
# N: 	 C_RelChange 	 R_RelChange 	 log_like 	 d_log_like 	 time(s)
# 0	 1.0326e+00	 6.8472e-05	 -5.2203e+04	 2.2187e+04	 0.20
# 100	 2.8387e-02	 2.3317e-02	 -2.9486e+04	 5.9691e+01	 20.08
# 200	 9.5611e-03	 1.4671e-02	 -2.6784e+04	 1.8121e+01	 42.70
# 300	 4.8116e-03	 4.9117e-03	 -2.6127e+04	 3.1694e+00	 62.17
# 400	 2.0443e-03	 2.2121e-03	 -2.5871e+04	 8.0532e-01	 81.77
# 500	 1.4572e-03	 1.1916e-03	 -2.5810e+04	 4.4374e-01	 101.49
# 600	 1.0563e-03	 1.0845e-03	 -2.5753e+04	 3.2583e-01	 120.93
# 700	 1.7685e-03	 1.3966e-03	 -2.5729e+04	 3.3807e-01	 140.62
# 800	 4.6787e-04	 8.7434e-04	 -2.5710e+04	 1.3258e-01	 160.05
# 900	 3.4429e-04	 4.4697e-04	 -2.5701e+04	 4.1341e-02	 179.56
# 1000	 3.0010e-04	 5.3173e-04	 -2.5694e+04	 5.0631e-02	 199.32
# 1100	 5.9481e-04	 6.8773e-04	 -2.5689e+04	 9.1178e-02	 219.17
# 1200	 6.5794e-04	 8.7142e-04	 -2.5657e+04	 3.0935e-01	 240.31
# 4.03475000064Minutes
# Stopping criterion met

# %%
LA_weights=np.sum(LA_matrix,(1,2))+np.sum(LA_matrix,(0,2))
LA_sizes=LA_weights/15;
LA_colors=LAc_fit/np.max(LAc_fit,0,keepdims=True)
scatterplot_city(LAc_fit,LA_N,numblocks,np.array([list(LA_station_info[x]) for x in LA_stations])
                     ,sizes=LA_sizes)
block_omegas(LAr_fit,numblocks)
# Out:
# 8

# %%
plt.figure(figsize=(10,10))

plt.plot(LAc_fit[:,4])
plt.plot(LAc_fit[:,2])
plt.figure()
plt.imshow(np.sum(LAr_fit,2))

# %%
LA_fit=[];
numiter=10000
numblocks=7
r0,c0=realistic_initial(LA_matrix,LA_N,numblocks)
LAr_fit7, LAc_fit7, wr, wc = \
gradient_descent(LA_matrix, r0, c0, N=numiter,sig_digs=3, N_stable=600, nblocks = numblocks, verbose_time = 100)
# Out:
# N: 	 C_RelChange 	 R_RelChange 	 log_like 	 d_log_like 	 time(s)
# 0	 1.6869e+00	 7.5072e-05	 -5.3343e+04	 2.2613e+04	 0.12
# 100	 1.7503e-02	 1.8600e-02	 -3.2031e+04	 3.9164e+01	 12.14
# 200	 2.6881e-03	 2.6250e-03	 -3.0137e+04	 2.1371e+00	 24.32
# 300	 4.6083e-03	 5.5860e-03	 -2.9920e+04	 2.5110e+00	 36.12
# 400	 4.5184e-03	 3.8109e-03	 -2.9466e+04	 2.6302e+00	 47.96
# 500	 2.2791e-03	 3.3472e-03	 -2.9319e+04	 1.3363e+00	 59.47
# 600	 3.0879e-03	 2.4861e-03	 -2.9187e+04	 3.2360e+00	 71.69
# 700	 3.7550e-03	 2.3280e-03	 -2.8487e+04	 3.5634e+00	 83.62
# 800	 7.4129e-04	 1.0461e-03	 -2.8309e+04	 5.1142e-01	 95.87
# 900	 4.1116e-04	 4.8398e-04	 -2.8273e+04	 1.6360e-01	 107.62
# 1000	 4.0627e-04	 2.7652e-04	 -2.8252e+04	 8.9639e-02	 119.21
# 1100	 2.0775e-04	 1.5373e-04	 -2.8247e+04	 4.2966e-02	 131.08
# 1200	 1.8085e-04	 1.3388e-04	 -2.8242e+04	 2.6937e-02	 142.54
# 1300	 1.4212e-04	 1.6361e-04	 -2.8240e+04	 2.5531e-02	 153.74
# 1400	 7.8570e-05	 7.7323e-05	 -2.8239e+04	 1.1685e-02	 164.87
# 1500	 5.7400e-05	 5.8207e-05	 -2.8238e+04	 6.3978e-03	 177.88
# 1600	 5.9713e-05	 8.1509e-05	 -2.8237e+04	 9.7611e-03	 189.73
# 3.20835000277Minutes
# Stopping criterion met

# %%
LA_weights=np.sum(LA_matrix,(1,2))+np.sum(LA_matrix,(0,2))
LA_sizes=LA_weights/15;
LA_colors=LAc_fit/np.max(LAc_fit,0,keepdims=True)
scatterplot_city(LAc_fit7,LA_N,numblocks,np.array([list(LA_station_info[x]) for x in LA_stations])
                     ,sizes=LA_sizes)
block_omegas(LAr_fit7,numblocks)
# Out:
# 7

# %%
plt.subplot()
plt.imshow(np.sum(LAr_fit7,2))
